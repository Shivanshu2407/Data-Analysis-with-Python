# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/Pc/Documents/country_comparison_large_dataset.csv')

# %%
df.head()
# Out:
#   Country  Year  GDP (in Trillions USD)  GDP per Capita (in USD)  \
# 0     USA  2000                   20.87                  65455.0
# 1  Russia  2000                    1.64                  10923.0
# 2  Canada  2000                    1.65                  47932.0
# 3   China  2000                   13.64                  10060.0
# 4   India  2000                    2.98                   2102.1
#
#    Inflation Rate (%)  Population (in Millions)  Population Growth Rate (%)  \
# 0                2.28                    330.34                        0.58
# 1                3.25                    141.81                        0.10
# 2                1.96                     36.63                        0.90
# 3                2.43                   1446.93                        0.31
# 4                4.87                   1313.76                        1.04
#
#    Urban Population (%)  Life Expectancy (Years)  \
# 0                 83.42                    78.39
# ...

# %%
df.tail(n=1)
# Out:
#        Country  Year  GDP (in Trillions USD)  GDP per Capita (in USD)  \
# 143  Australia  2023                    1.27                  51304.0
#
#      Inflation Rate (%)  Population (in Millions)  Population Growth Rate (%)  \
# 143                1.54                     24.38                        1.36
#
#      Urban Population (%)  Life Expectancy (Years)  \
# 143                 84.37                     83.4
#
#      Healthcare Expenditure per Capita (USD)  ...  Poverty Rate (%)  \
# 143                                   5434.0  ...              9.99
#
#      Number of International Visitors (in Millions)  \
# 143                                            9.77
#
#      Tourism Revenue (in Billion USD)  Agricultural Land (%)  \
# 143                             58.26                   53.8
#
#      Unemployment Rate (%)  Labor Force Participation Rate (%)  \
# 143                   4.75                               69.23
#
# ...

# %%
df.loc[[0,99]]
# Out:
#    Country  Year  GDP (in Trillions USD)  GDP per Capita (in USD)  \
# 0      USA  2000                   20.87                  65455.0
# 99   China  2016                   14.34                   9520.0
#
#     Inflation Rate (%)  Population (in Millions)  Population Growth Rate (%)  \
# 0                 2.28                    330.34                        0.58
# 99                2.36                   1438.54                        0.29
#
#     Urban Population (%)  Life Expectancy (Years)  \
# 0                  83.42                    78.39
# 99                 57.96                    76.70
#
#     Healthcare Expenditure per Capita (USD)  ...  Poverty Rate (%)  \
# 0                                   11209.0  ...             10.98
# 99                                    428.4  ...              2.03
#
#     Number of International Visitors (in Millions)  \
# 0                                            80.80
# 99                                           65.84
#
# ...

# %%
df.iloc[1]
# Out:
# Country                                              Russia
# Year                                                   2000
# GDP (in Trillions USD)                                 1.64
# GDP per Capita (in USD)                             10923.0
# Inflation Rate (%)                                     3.25
# Population (in Millions)                             141.81
# Population Growth Rate (%)                              0.1
# Urban Population (%)                                  72.67
# Life Expectancy (Years)                               69.91
# Healthcare Expenditure per Capita (USD)              534.45
# Doctor-to-Patient Ratio                                4.05
# Literacy Rate (%)                                    103.55
# Education Expenditure as % of GDP                      4.37
# Internet Penetration (%)                              84.84
# Smartphone Adoption (%)                               72.88
# Energy Consumption (TWh)                             1058.4
# ...

# %%
df.loc[1]
# Out:
# Country                                              Russia
# Year                                                   2000
# GDP (in Trillions USD)                                 1.64
# GDP per Capita (in USD)                             10923.0
# Inflation Rate (%)                                     3.25
# Population (in Millions)                             141.81
# Population Growth Rate (%)                              0.1
# Urban Population (%)                                  72.67
# Life Expectancy (Years)                               69.91
# Healthcare Expenditure per Capita (USD)              534.45
# Doctor-to-Patient Ratio                                4.05
# Literacy Rate (%)                                    103.55
# Education Expenditure as % of GDP                      4.37
# Internet Penetration (%)                              84.84
# Smartphone Adoption (%)                               72.88
# Energy Consumption (TWh)                             1058.4
# ...

# %%
df.iloc[99]
# Out:
# Country                                               China
# Year                                                   2016
# GDP (in Trillions USD)                                14.34
# GDP per Capita (in USD)                              9520.0
# Inflation Rate (%)                                     2.36
# Population (in Millions)                            1438.54
# Population Growth Rate (%)                             0.29
# Urban Population (%)                                  57.96
# Life Expectancy (Years)                                76.7
# Healthcare Expenditure per Capita (USD)               428.4
# Doctor-to-Patient Ratio                                1.88
# Literacy Rate (%)                                      93.7
# Education Expenditure as % of GDP                      3.98
# Internet Penetration (%)                              62.66
# Smartphone Adoption (%)                               72.31
# Energy Consumption (TWh)                             6949.6
# ...

# %%
df.iloc[-1]
# Out:
# Country                                           Australia
# Year                                                   2023
# GDP (in Trillions USD)                                 1.27
# GDP per Capita (in USD)                             51304.0
# Inflation Rate (%)                                     1.54
# Population (in Millions)                              24.38
# Population Growth Rate (%)                             1.36
# Urban Population (%)                                  84.37
# Life Expectancy (Years)                                83.4
# Healthcare Expenditure per Capita (USD)              5434.0
# Doctor-to-Patient Ratio                                3.53
# Literacy Rate (%)                                     94.35
# Education Expenditure as % of GDP                      4.94
# Internet Penetration (%)                              86.81
# Smartphone Adoption (%)                                87.2
# Energy Consumption (TWh)                              307.5
# ...

# %%
subset = df.loc[:, ['Country','Year','Population (in Millions)']]

# %%
subset.head()
# Out:
#   Country  Year  Population (in Millions)
# 0     USA  2000                    330.34
# 1  Russia  2000                    141.81
# 2  Canada  2000                     36.63
# 3   China  2000                   1446.93
# 4   India  2000                   1313.76

# %%
subset = df.iloc[:,[0,1,2]]

# %%
subset.head()
# Out:
#   Country  Year  GDP (in Trillions USD)
# 0     USA  2000                   20.87
# 1  Russia  2000                    1.64
# 2  Canada  2000                    1.65
# 3   China  2000                   13.64
# 4   India  2000                    2.98

# %%
small_range = list(range(10))

# %%
subset = df.iloc[:, small_range]

# %%
subset.head()
# Out:
#   Country  Year  GDP (in Trillions USD)  GDP per Capita (in USD)  \
# 0     USA  2000                   20.87                  65455.0
# 1  Russia  2000                    1.64                  10923.0
# 2  Canada  2000                    1.65                  47932.0
# 3   China  2000                   13.64                  10060.0
# 4   India  2000                    2.98                   2102.1
#
#    Inflation Rate (%)  Population (in Millions)  Population Growth Rate (%)  \
# 0                2.28                    330.34                        0.58
# 1                3.25                    141.81                        0.10
# 2                1.96                     36.63                        0.90
# 3                2.43                   1446.93                        0.31
# 4                4.87                   1313.76                        1.04
#
#    Urban Population (%)  Life Expectancy (Years)  \
# 0                 83.42                    78.39
# ...

# %%
print(df.loc[2, 'Country'])
# Out:
# Canada

# %%
df.loc[0, 'Country']
# Out:
# 'USA'

# %%
df.iloc[[0,1,2], [0,2,3,4,5]]
# Out:
#   Country  GDP (in Trillions USD)  GDP per Capita (in USD)  \
# 0     USA                   20.87                  65455.0
# 1  Russia                    1.64                  10923.0
# 2  Canada                    1.65                  47932.0
#
#    Inflation Rate (%)  Population (in Millions)
# 0                2.28                    330.34
# 1                3.25                    141.81
# 2                1.96                     36.63

# %%
df.loc[[0,9,99],['Country','Year','GDP (in Trillions USD)',	'GDP per Capita (in USD)',	'Inflation Rate (%)',	'Population (in Millions)']]
# Out:
#    Country  Year  GDP (in Trillions USD)  GDP per Capita (in USD)  \
# 0      USA  2000                   20.87                  65455.0
# 9    China  2001                   14.00                  10390.0
# 99   China  2016                   14.34                   9520.0
#
#     Inflation Rate (%)  Population (in Millions)
# 0                 2.28                    330.34
# 9                 2.33                   1437.14
# 99                2.36                   1438.54

# %%
df.head(n=10)
# Out:
#      Country  Year  GDP (in Trillions USD)  GDP per Capita (in USD)  \
# 0        USA  2000                   20.87                  65455.0
# 1     Russia  2000                    1.64                  10923.0
# 2     Canada  2000                    1.65                  47932.0
# 3      China  2000                   13.64                  10060.0
# 4      India  2000                    2.98                   2102.1
# 5  Australia  2000                    1.38                  51039.0
# 6        USA  2001                   22.01                  66365.0
# 7     Russia  2001                    1.66                  10890.0
# 8     Canada  2001                    1.72                  45034.0
# 9      China  2001                   14.00                  10390.0
#
#    Inflation Rate (%)  Population (in Millions)  Population Growth Rate (%)  \
# 0                2.28                    330.34                        0.58
# ...

# %%
# For each year in our data, what is the average Life Expectency

# %%
df.groupby('Year')['Life Expectancy (Years)'].mean()
# Out:
# Year
# 2000    76.445000
# 2001    77.231667
# 2002    78.125000
# 2003    76.483333
# 2004    78.016667
# 2005    78.045000
# 2006    77.558333
# 2007    77.753333
# 2008    75.965000
# 2009    76.581667
# 2010    77.321667
# 2011    77.198333
# 2012    79.046667
# 2013    76.433333
# 2014    78.496667
# 2015    77.438333
# 2016    76.308333
# 2017    77.863333
# 2018    77.460000
# 2019    77.521667
# 2020    77.750000
# 2021    77.730000
# 2022    76.331667
# 2023    76.651667
# Name: Life Expectancy (Years), dtype: float64

# %%
multi_group_var = df.groupby(['Year', 'Country'])[['GDP (in Trillions USD)',\
'GDP per Capita (in USD)',	'Inflation Rate (%)',	'Population (in Millions)',	'Population Growth Rate (%)']].mean()

# %%
multi_group_var
# Out:
#                 GDP (in Trillions USD)  GDP per Capita (in USD)  \
# Year Country
# 2000 Australia                    1.38                  51039.0
#      Canada                       1.65                  47932.0
#      China                       13.64                  10060.0
#      India                        2.98                   2102.1
#      Russia                       1.64                  10923.0
# ...                                ...                      ...
# 2023 Canada                       1.73                  44804.0
#      China                       13.72                   9870.0
#      India                        2.79                   2070.6
#      Russia                       1.64                  10978.0
#      USA                         21.17                  63245.0
#
#                 Inflation Rate (%)  Population (in Millions)  \
# Year Country
# 2000 Australia                1.54                     26.15
# ...

# %%
multi_group_var.head(24)
# Out:
#                 GDP (in Trillions USD)  GDP per Capita (in USD)  \
# Year Country
# 2000 Australia                    1.38                  51039.0
#      Canada                       1.65                  47932.0
#      China                       13.64                  10060.0
#      India                        2.98                   2102.1
#      Russia                       1.64                  10923.0
#      USA                         20.87                  65455.0
# 2001 Australia                    1.34                  53901.0
#      Canada                       1.72                  45034.0
#      China                       14.00                  10390.0
#      India                        3.00                   2135.7
#      Russia                       1.66                  10890.0
#      USA                         22.01                  66365.0
# 2002 Australia                    1.36                  51145.0
# ...

# %%
flat = multi_group_var.reset_index()

# %%
flat
# Out:
#      Year    Country  GDP (in Trillions USD)  GDP per Capita (in USD)  \
# 0    2000  Australia                    1.38                  51039.0
# 1    2000     Canada                    1.65                  47932.0
# 2    2000      China                   13.64                  10060.0
# 3    2000      India                    2.98                   2102.1
# 4    2000     Russia                    1.64                  10923.0
# ..    ...        ...                     ...                      ...
# 139  2023     Canada                    1.73                  44804.0
# 140  2023      China                   13.72                   9870.0
# 141  2023      India                    2.79                   2070.6
# 142  2023     Russia                    1.64                  10978.0
# 143  2023        USA                   21.17                  63245.0
#
#      Inflation Rate (%)  Population (in Millions)  Population Growth Rate (%)
# ...

# %%
df.describe()
# Out:
#               Year  GDP (in Trillions USD)  GDP per Capita (in USD)  \
# count   144.000000              144.000000               144.000000
# mean   2011.500000                7.186667             31118.720139
# std       6.946348                7.807163             24438.786379
# min    2000.000000                1.270000              2009.700000
# 25%    2005.750000                1.630000              9972.500000
# 50%    2011.500000                2.275000             27548.000000
# 75%    2017.250000               14.232500             52231.500000
# max    2023.000000               22.240000             68120.000000
#
#        Inflation Rate (%)  Population (in Millions)  \
# count          144.000000                144.000000
# mean             2.653125                550.913542
# std              1.067940                600.169798
# min              1.440000                 23.900000
# 25%              1.887500                 37.342500
# ...

# %%
print(df.groupby('Year')['Country'].unique())
# Out:
# Year
# 2000    [USA, Russia, Canada, China, India, Australia]
# 2001    [USA, Russia, Canada, China, India, Australia]
# 2002    [USA, Russia, Canada, China, India, Australia]
# 2003    [USA, Russia, Canada, China, India, Australia]
# 2004    [USA, Russia, Canada, China, India, Australia]
# 2005    [USA, Russia, Canada, China, India, Australia]
# 2006    [USA, Russia, Canada, China, India, Australia]
# 2007    [USA, Russia, Canada, China, India, Australia]
# 2008    [USA, Russia, Canada, China, India, Australia]
# 2009    [USA, Russia, Canada, China, India, Australia]
# 2010    [USA, Russia, Canada, China, India, Australia]
# 2011    [USA, Russia, Canada, China, India, Australia]
# 2012    [USA, Russia, Canada, China, India, Australia]
# 2013    [USA, Russia, Canada, China, India, Australia]
# 2014    [USA, Russia, Canada, China, India, Australia]
# 2015    [USA, Russia, Canada, China, India, Australia]
# 2016    [USA, Russia, Canada, China, India, Australia]
# ...

# %%
global_yearly_life_expectency = df.groupby('Year')['Life Expectancy (Years)'].mean()

# %%
global_yearly_life_expectency
# Out:
# Year
# 2000    76.445000
# 2001    77.231667
# 2002    78.125000
# 2003    76.483333
# 2004    78.016667
# 2005    78.045000
# 2006    77.558333
# 2007    77.753333
# 2008    75.965000
# 2009    76.581667
# 2010    77.321667
# 2011    77.198333
# 2012    79.046667
# 2013    76.433333
# 2014    78.496667
# 2015    77.438333
# 2016    76.308333
# 2017    77.863333
# 2018    77.460000
# 2019    77.521667
# 2020    77.750000
# 2021    77.730000
# 2022    76.331667
# 2023    76.651667
# Name: Life Expectancy (Years), dtype: float64

# %%
global_yearly_life_expectency.plot()
# Out:
# <Axes: xlabel='Year'>
